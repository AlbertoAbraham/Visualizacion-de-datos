# %% [markdown]
# # Gestion de datos

# %%
# %ls
# Out:
#  00_00_primer_pasos.ipynb               coches.csv
#  01_01_data_types.ipynb                 cwurData.csv
#  01_02_read_iloc_unique_groupby.ipynb   data.csv
#  02_00_data_wrangling.ipynb             headbrain.csv
#  02_01_null_display.ipynb               mic2.xlsx
#  02_02_basic_math.ipynb                 mic.xlsx
#  adult.csv                              movies.csv
#  airline_data.csv                       nhanes_2015_2016.csv
#  antropometria00.csv                    pokemon.csv
#  antropometria-dataset.csv              README.md
#  Book3.csv                             'requirements (1).txt'
#  Canada.xlsx                            sample_pivot.csv
#  Cartwheeldata.csv                      tips.csv
#  census.csv                             Untitled.ipynb
#  Clase_2.ipynb                          weight-height.csv

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
path = 'Cartwheeldata.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x = df.columns
type(x)
# Out:
# pandas.core.indexes.base.Index

# %%
x = list(df.columns)
type(x)
# Out:
# list

# %%
print(x)
# Out:
# ['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup', 'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup', 'Score']

# %% [markdown]
# # variables de interes

# %% [markdown]
# ### usamos iloc y loc

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df['Age'].head()
# Out:
# 0    56
# 1    26
# 2    33
# 3    39
# 4    27
# Name: Age, dtype: int64

# %%
df[['Age','Height', 'CWDistance']].head()
# Out:
#    Age  Height  CWDistance
# 0   56    62.0          79
# 1   26    62.0          70
# 2   33    66.0          85
# 3   39    64.0          87
# 4   27    73.0          72

# %%
df[['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses']].head()
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 0   1   56      F            1       Y
# 1   2   26      F            1       Y
# 2   3   33      F            1       Y
# 3   4   39      F            1       N
# 4   5   27      M            2       N

# %% [markdown]
# ### sitaxis de loc es
# ### [ row_initial:row_final , col_initial:col_final]
#
# nombres de las columnas y los renglones

# %%
ndf = df.loc[: , :'Glasses']
ndf.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 0   1   56      F            1       Y
# 1   2   26      F            1       Y
# 2   3   33      F            1       Y
# 3   4   39      F            1       N
# 4   5   27      M            2       N

# %% [markdown]
# ### sitaxis de iloc es
# ### [ row_initial:row_final , col_initial:col_final]
#
# indices de las columnas y renglones

# %%
ndf = df.iloc[3:5 , :5]
ndf
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 3   4   39      F            1       N
# 4   5   27      M            2       N
